# %% [markdown]
# # Práctica 1.1 — Probabilidad y Estadística
# ## Análisis de la evolución poblacional mundial
#
# ### Objetivo
#
# Utilizar un conjunto de datos real para comprobar el funcionamiento del entorno de análisis de datos y aplicar medidas estadísticas descriptivas básicas utilizando Pandas y NumPy.

# %% [markdown]
# ## Actividad 1. Identificación de la fuente
# ### Propósito
#
# Reconocer la procedencia del conjunto de datos antes de utilizarlo y documentar correctamente su fuente.

# %% [markdown]
# ### Fuente de datos
#
# Los datos utilizados en esta práctica provienen de **Our World in Data (OWID)**.
#
# La fuente original es **United Nations, World Population Prospects (2024)**.
#
# **Cita:**
#
# > UN, World Population Prospects (2024) – processed by Our World in Data. “Annual change in population – UN WPP” [dataset]. United Nations, “World Population Prospects”; United Nations, “World Population Prospects - Interim Update” [original data].

# %% [markdown]
# ### Preguntas
#
# **1. ¿Quién produjo originalmente los datos?**
#
# **2. ¿Qué organización los procesa para su utilización en Our World in Data?**
#
# **3. ¿Qué representa la variable que analizarás?**

# %% [markdown]
# # Actividad 2 — Carga y exploración de datos
#
# ### Propósito
#
# Comprobar que el entorno de Python, Pandas y Jupyter funciona correctamente y realizar una primera exploración del conjunto de datos.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/annual-population-growth/annual-population-growth.csv")

# %%
df.head(3)
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN

# %%
df.tail()
# Out:
#          Entity Code  Year  Annual change in population  \
# 38395  Zimbabwe  ZWE  2096                          NaN
# 38396  Zimbabwe  ZWE  2097                          NaN
# 38397  Zimbabwe  ZWE  2098                          NaN
# 38398  Zimbabwe  ZWE  2099                          NaN
# 38399  Zimbabwe  ZWE  2100                          NaN
#
#        Annual population change (Projected)
# 38395                              100752.0
# 38396                               91796.0
# 38397                               87605.0
# 38398                               76670.0
# 38399                               70019.0

# %%
df.shape
# Out:
# (38400, 5)

# %%
df.columns.tolist()
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Annual change in population',
#  'Annual population change (Projected)']

# %%
df.dtypes
# Out:
# Entity                                      str
# Code                                        str
# Year                                      int64
# Annual change in population             float64
# Annual population change (Projected)    float64
# dtype: object

# %%
df.describe()
# Out:
#                Year  Annual change in population  \
# count  38400.000000                 1.868800e+04
# mean    2025.500000                 2.063019e+06
# std       43.300872                 9.440859e+06
# min     1951.000000                -3.315935e+06
# 25%     1988.000000                 1.781000e+03
# 50%     2025.500000                 4.689800e+04
# 75%     2063.000000                 3.021128e+05
# max     2100.000000                 9.337137e+07
#
#        Annual population change (Projected)
# count                          1.971200e+04
# mean                           8.375481e+05
# std                            5.816745e+06
# min                           -2.291035e+07
# 25%                           -9.742750e+03
# 50%                            9.350000e+01
# 75%                            1.411160e+05
# max                            7.206736e+07

# %%
df.isnull().sum()
# Out:
# Entity                                      0
# Code                                     1200
# Year                                        0
# Annual change in population             19712
# Annual population change (Projected)    18688
# dtype: int64

# %%
df["Entity"].nunique()
# Out:
# 256

# %% [markdown]
# ### Preguntas
#
# **1. ¿Cuántas filas y columnas tiene el dataset?**
#
# **2. ¿Qué tipo de datos contiene la variable `Year`?**
#
# **3. ¿Existen valores faltantes?**
#
# **4. ¿Cuántas entidades diferentes contiene el dataset?**

# %% [markdown]
# # Actividad 3 — Estadística descriptiva
#
# ### Propósito
#
# Aplicar medidas estadísticas básicas a la variable histórica de cambio anual de población.

# %% [markdown]
# Hagamos un filtro para obtener un data frame que corresponda a los datos de la Entidad "Mexico" y que sean datos a partir de 1980.

# %%
df.head(3)
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN

# %%
df_extraccion_entity = df[["Entity","Year"]]
df_extraccion_entity
# Out:
#             Entity  Year
# 0      Afghanistan  1951
# 1      Afghanistan  1952
# 2      Afghanistan  1953
# 3      Afghanistan  1954
# 4      Afghanistan  1955
# ...            ...   ...
# 38395     Zimbabwe  2096
# 38396     Zimbabwe  2097
# 38397     Zimbabwe  2098
# 38398     Zimbabwe  2099
# 38399     Zimbabwe  2100
#
# [38400 rows x 2 columns]

# %%
df_2020 = df[df["Year"]==2020 ]
df_2020.head(3)
# Out:
#           Entity    Code  Year  Annual change in population  \
# 69   Afghanistan     AFG  2020                    1212852.0
# 219  Africa (UN)  UN_AFR  2020                   32815675.0
# 369      Albania     ALB  2020                     -13061.0
#
#      Annual population change (Projected)
# 69                                    NaN
# 219                                   NaN
# 369                                   NaN

# %%
df_2020_ext_col1 = df_2020[["Entity","Year"]]
df_2020_ext_col1.head(3)
df_2020_ext_col2 = df[df["Year"]==2020 ][["Entity","Year"]]
df_2020_ext_col2.shape
# Out:
# (256, 2)

# %%
df_2005_2020 = df[ (df["Year"] >= 2005) & (df["Year"] <= 2020) & (df["Entity"] == "Mexico")]
df_2005_2020.shape
# Out:
# (16, 5)

# %%
df_2005_2020.head(3)
# Out:
#          Entity Code  Year  Annual change in population  \
# 54  Afghanistan  AFG  2005                     843919.0
# 55  Afghanistan  AFG  2006                    1019525.0
# 56  Afghanistan  AFG  2007                     485752.0
#
#     Annual population change (Projected)
# 54                                   NaN
# 55                                   NaN
# 56                                   NaN

# %%
df_ext_EA = df_2005_2020[["Entity","Annual change in population"]]
df_ext_EA.head(3)
# Out:
#        Entity  Annual change in population
# 22254  Mexico                    1417373.0
# 22255  Mexico                    1442162.0
# 22256  Mexico                    1520690.0

# %%
df_ext_EA.mean(numeric_only=True)
# Out:
# Annual change in population    1400307.625
# dtype: float64

# %%
df_mex.mean(numeric_only=True)
# Out:
# Year                           2.001500e+03
# Annual change in population    1.456611e+06
# dtype: float64

# %%
anio_consultado = 2020

# %%
df_new = df[["Entity"]]
df_new
# Out:
#             Entity
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
# ...            ...
# 38395     Zimbabwe
# 38396     Zimbabwe
# 38397     Zimbabwe
# 38398     Zimbabwe
# 38399     Zimbabwe
#
# [38400 rows x 1 columns]

# %%
df.loc[:,["Entity","Year"]]
# Out:
#             Entity  Year
# 0      Afghanistan  1951
# 1      Afghanistan  1952
# 2      Afghanistan  1953
# 3      Afghanistan  1954
# 4      Afghanistan  1955
# ...            ...   ...
# 38395     Zimbabwe  2096
# 38396     Zimbabwe  2097
# 38397     Zimbabwe  2098
# 38398     Zimbabwe  2099
# 38399     Zimbabwe  2100
#
# [38400 rows x 2 columns]

# %%
df.loc[20000:35000]
# Out:
#                      Entity      Code  Year  Annual change in population  \
# 20000  Low-income countries  OWID_LIC  2001                   10677553.0
# 20001  Low-income countries  OWID_LIC  2002                   11913571.0
# 20002  Low-income countries  OWID_LIC  2003                   12406252.0
# 20003  Low-income countries  OWID_LIC  2004                   12305744.0
# 20004  Low-income countries  OWID_LIC  2005                   12772824.0
# ...                     ...       ...   ...                          ...
# 34996                Turkey       TUR  1997                     901834.0
# 34997                Turkey       TUR  1998                     881417.0
# 34998                Turkey       TUR  1999                     857531.0
# 34999                Turkey       TUR  2000                     834041.0
# 35000                Turkey       TUR  2001                     819168.0
#
#        Annual population change (Projected)
# 20000                                   NaN
# ...

# %%
df.iloc[10000]
# Out:
# Entity                                  Equatorial Guinea
# Code                                                  GNQ
# Year                                                 2051
# Annual change in population                           NaN
# Annual population change (Projected)              46407.0
# Name: 10000, dtype: object

# %%
df.loc[:,["Entity","Year","Annual change in population"]]
# Out:
#             Entity  Year  Annual change in population
# 0      Afghanistan  1951                     103163.0
# 1      Afghanistan  1952                     108441.0
# 2      Afghanistan  1953                     108919.0
# 3      Afghanistan  1954                     111251.0
# 4      Afghanistan  1955                     119027.0
# ...            ...   ...                          ...
# 38395     Zimbabwe  2096                          NaN
# 38396     Zimbabwe  2097                          NaN
# 38397     Zimbabwe  2098                          NaN
# 38398     Zimbabwe  2099                          NaN
# 38399     Zimbabwe  2100                          NaN
#
# [38400 rows x 3 columns]

# %%
df.loc[10000,["Entity","Year","Annual change in population"]]
# Out:
# Entity                         Equatorial Guinea
# Year                                        2051
# Annual change in population                  NaN
# Name: 10000, dtype: object

# %%
dff = df[(df["Year"]>=2005) & (df["Year"]<=2023) & (df["Entity"]=="Mexico")]

# %%
dff = df[(df["Year"]>=2005) & (df["Year"]<=2023) & (df["Entity"] == "Mexico")][["Annual change in population"]]
dff.head()
# Out:
#        Annual change in population
# 22254                    1417373.0
# 22255                    1442162.0
# 22256                    1520690.0
# 22257                    1599930.0
# 22258                    1625434.0

# %%
print(dff.mean())
print(dff.median())
print(dff.var())
print(dff.std())
print(dff.min())
print(dff.max())
# Out:
# Annual change in population    1.333981e+06
# dtype: float64
# Annual change in population    1417373.0
# dtype: float64
# Annual change in population    6.061445e+10
# dtype: float64
# Annual change in population    246200.028553
# dtype: float64
# Annual change in population    849098.0
# dtype: float64
# Annual change in population    1625434.0
# dtype: float64

# %%
df_mex.columns.to_list()
# Out:
# ['Entity', 'Year', 'Annual change in population']

# %% [markdown]
# 1.	¿Cuál es el valor de la media?  1 333 981
# 2.	¿Cuál es el valor de la mediana?  1 417 373
# 3.	¿Cuál es el valor de la desviación estándar? 246 200
# 4.	¿Qué entidad presenta el valor mínimo y cuál el máximo? minimo 849 098
# máximo 1 625 434

# %%
df.loc[df["Entity"]=="Morocco"]
# Out:
#         Entity Code  Year  Annual change in population  \
# 23400  Morocco  MAR  1951                     223837.0
# 23401  Morocco  MAR  1952                     235589.0
# 23402  Morocco  MAR  1953                     244689.0
# 23403  Morocco  MAR  1954                     253748.0
# 23404  Morocco  MAR  1955                     264811.0
# ...        ...  ...   ...                          ...
# 23545  Morocco  MAR  2096                          NaN
# 23546  Morocco  MAR  2097                          NaN
# 23547  Morocco  MAR  2098                          NaN
# 23548  Morocco  MAR  2099                          NaN
# 23549  Morocco  MAR  2100                          NaN
#
#        Annual population change (Projected)
# 23400                                   NaN
# 23401                                   NaN
# 23402                                   NaN
# 23403                                   NaN
# 23404                                   NaN
# ...

# %% [markdown]
# **Variable de análisis**

# %%
import sys

print("Python:", sys.version)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Python: 3.12.0 (v3.12.0:0fb18b02c8, Oct  2 2023, 09:45:56) [Clang 13.0.0 (clang-1300.0.29.30)]
# Pandas: 3.0.5
# NumPy: 2.5.2

# %%
df_mex_acp_2020 = df_anio_consultado[["Annual change in population"]]

# %%
cambio_poblacion_anio_consultado = df_anio_consultado["Annual change in population"]

# %%
type(cambio_poblacion_anio_consultado)
# Out:
# pandas.Series

# %% [markdown]
# ### Calcular los estadísticos

# %%
media = cambio_poblacion_anio_consultado.mean()
mediana = cambio_poblacion_anio_consultado.median()
varianza = cambio_poblacion_anio_consultado.var()
desviacion_estandar = cambio_poblacion_anio_consultado.std()
minimo = cambio_poblacion_anio_consultado.min()
maximo = cambio_poblacion_anio_consultado.max()

print("Media:", media)
print("Mediana:", mediana)
print("Varianza:", varianza)
print("Desviación estándar:", desviacion_estandar)
print("Mínimo:", minimo)
print("Máximo:", maximo)
# Out:
# Media: 1036075.0
# Mediana: 1036075.0
# Varianza: nan
# Desviación estándar: nan
# Mínimo: 1036075.0
# Máximo: 1036075.0

# %% [markdown]
# ### Encontrar las entidades con mínimo y máximo

# %%
fila_minimo = df_anio_consultado.loc[df_anio_consultado["Annual change in population"].idxmin()]
fila_maximo = df_anio_consultado.loc[df_anio_consultado["Annual change in population"].idxmax()]

print("Entidad con el valor mínimo:", fila_minimo["Entity"])
print("Valor mínimo:", fila_minimo["Annual change in population"])

print("Entidad con el valor máximo:", fila_maximo["Entity"])
print("Valor máximo:", fila_maximo["Annual change in population"])
# Out:
# Entidad con el valor mínimo: Venezuela
# Valor mínimo: -494016.0
# Entidad con el valor máximo: World
# Valor máximo: 75707590.0

# %%
print(fila_maximo)
# Out:
# Entity                                       World
# Code                                      OWID_WRL
# Year                                          2020
# Annual change in population             75707590.0
# Annual population change (Projected)           NaN
# Name: 37869, dtype: object

# %%
print(fila_minimo)
# Out:
# Entity                                  Venezuela
# Code                                          VEN
# Year                                         2020
# Annual change in population             -494016.0
# Annual population change (Projected)          NaN
# Name: 37269, dtype: object

# %% [markdown]
# ### Preguntas
#
# **1. ¿Cuál es el valor de la media?**
#
# **2. ¿Cuál es el valor de la mediana?**
#
# **3. ¿Cuál es el valor de la desviación estándar?**
#
# **4. ¿Qué entidad presenta el valor mínimo y cuál el máximo?**

# %% [markdown]
# # Actividad 4 — Comprobación del entorno
#
# ### Propósito
#
# Comprobar que el notebook está utilizando correctamente las herramientas configuradas para la práctica.

# %%
import sys

print("Python:", sys.version)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Python: 3.12.0 (v3.12.0:0fb18b02c8, Oct  2 2023, 09:45:56) [Clang 13.0.0 (clang-1300.0.29.30)]
# Pandas: 3.0.5
# NumPy: 2.5.2

# %% [markdown]
# # Resultados
#
# En esta práctica se cargó y exploró un conjunto de datos reales sobre el cambio anual de población. Se identificó la fuente de los datos, se revisó la estructura del DataFrame y se calcularon medidas estadísticas descriptivas para un año seleccionado.
#
# También se comprobaron las versiones de Python, Pandas y NumPy utilizadas por el notebook.

# %%
df.head()
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
# 4  Afghanistan  AFG  1955                     119027.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
df.loc[600:610,["Entity","Year"]]
# Out:
#              Entity  Year
# 600  American Samoa  1951
# 601  American Samoa  1952
# 602  American Samoa  1953
# 603  American Samoa  1954
# 604  American Samoa  1955
# 605  American Samoa  1956
# 606  American Samoa  1957
# 607  American Samoa  1958
# 608  American Samoa  1959
# 609  American Samoa  1960
# 610  American Samoa  1961

# %%
df.iloc[10000]
# Out:
# Entity                                  Equatorial Guinea
# Code                                                  GNQ
# Year                                                 2051
# Annual change in population                           NaN
# Annual population change (Projected)              46407.0
# Name: 10000, dtype: object

# %%
df.loc[:,["Entity","Year","Annual change in population"]]
# Out:
#             Entity  Year  Annual change in population
# 0      Afghanistan  1951                     103163.0
# 1      Afghanistan  1952                     108441.0
# 2      Afghanistan  1953                     108919.0
# 3      Afghanistan  1954                     111251.0
# 4      Afghanistan  1955                     119027.0
# ...            ...   ...                          ...
# 38395     Zimbabwe  2096                          NaN
# 38396     Zimbabwe  2097                          NaN
# 38397     Zimbabwe  2098                          NaN
# 38398     Zimbabwe  2099                          NaN
# 38399     Zimbabwe  2100                          NaN
#
# [38400 rows x 3 columns]

# %%
df.iloc[:,[0,2,3]]
# Out:
#             Entity  Year  Annual change in population
# 0      Afghanistan  1951                     103163.0
# 1      Afghanistan  1952                     108441.0
# 2      Afghanistan  1953                     108919.0
# 3      Afghanistan  1954                     111251.0
# 4      Afghanistan  1955                     119027.0
# ...            ...   ...                          ...
# 38395     Zimbabwe  2096                          NaN
# 38396     Zimbabwe  2097                          NaN
# 38397     Zimbabwe  2098                          NaN
# 38398     Zimbabwe  2099                          NaN
# 38399     Zimbabwe  2100                          NaN
#
# [38400 rows x 3 columns]

# %%
df.loc[10000,["Entity","Year","Annual change in population"]]
# Out:
# Entity                         Equatorial Guinea
# Year                                        2051
# Annual change in population                  NaN
# Name: 10000, dtype: object

# %%
df.iloc[10000,[0,2,3]]
# Out:
# Entity                         Equatorial Guinea
# Year                                        2051
# Annual change in population                  NaN
# Name: 10000, dtype: object

# %%
df.loc[(df["Entity"]== "Mexico") & (df["Year"]== 2000)]
# Out:
#        Entity Code  Year  Annual change in population  \
# 22249  Mexico  MEX  2000                    1509843.0
#
#        Annual population change (Projected)
# 22249                                   NaN

# %%
df.iloc[22249]
# Out:
# Entity                                     Mexico
# Code                                          MEX
# Year                                         2000
# Annual change in population             1509843.0
# Annual population change (Projected)          NaN
# Name: 22249, dtype: object

# %%
type(df.iloc[22249])
# Out:
# pandas.Series

# %%
df.iloc[10:15,0:1]
# Out:
#          Entity
# 10  Afghanistan
# 11  Afghanistan
# 12  Afghanistan
# 13  Afghanistan
# 14  Afghanistan
